# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 100)
plt.plot(x, 1 / (1 + np.exp(-x)), label='Sigmoid')
plt.plot(x, np.tanh(x), label='tanh')
plt.plot(x, np.maximum(0, x), label='ReLU')
plt.plot(x, x, label='Identity')
plt.plot(x, np.exp(x) / np.sum(np.exp(x)), label='Softmax')

plt.xlabel('Input')
plt.ylabel('Activation')
plt.title('Activation Functions')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.plot(x, np.maximum(0, x), label='ReLU')

# %%
# linear activation function

# %%
def linear_function(x):
    return 2*x

linear_function(3), linear_function(-3), linear_function(0), linear_function(6)
# Out:
# (6, -6, 0, 12)

# %%
# nonlinear activation function

# %%
# sigmoid activation function
import numpy as np
def sigmoid(x):
    return 1/(1+np.exp(-x))

sigmoid(3),sigmoid(-3)
# Out:
# (0.9525741268224334, 0.04742587317756678)

# %%
0.9525741268224334 + 0.04742587317756678
# Out:
# 1.0000000000000002

# %%
## Softmax activation function
def softmax(x):
    a = np.exp(x)
    b = a/ a.sum()
    return b

softmax([3,-3])
# Out:
# array([0.99752738, 0.00247262])

# %%
0.99752738+ 0.00247262
# Out:
# 1.0

# %%
softmax([3,-3,0])
# Out:
# array([0.95033021, 0.00235563, 0.04731416])

# %%
0.95033021+0.00235563+0.04731416
# Out:
# 1.0

# %%
softmax([3,-3,0,6,8])
# Out:
# array([5.89793174e-03, 1.46195111e-05, 2.93640731e-04, 1.18463126e-01,
#        8.75330682e-01])

# %%
5.89793174e-03+1.46195111e-05+2.93640731e-04+1.18463126e-01+8.75330682e-01
# Out:
# 0.9999999999821

# %%
## Tanh activation function
def tanh(x):
    return 2* (1/(1+np.exp(-2 * x))) - 1

tanh(3),tanh(-3), tanh(0), tanh(6)
# Out:
# (0.9950547536867307, -0.9950547536867305, 0.0, 0.9999877116507956)

# %%
## Relu sctivation function
def ReLU(x):
    return max(0,x)

ReLU(3),ReLU(-3),ReLU(9),ReLU(-7)
# Out:
# (3, 0, 9, 0)
